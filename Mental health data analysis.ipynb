# %% [markdown]
# # Data cleaning and processing

# %%
#import required libraries
import pandas as pd
import numpy as np

# %%
#load the dataset
df = pd.read_csv('MENTAL HEALTH DATASET.csv')

# %%
df
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
#summary info of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   object
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   object
#  3   Country                    1259 non-null   object
#  4   state                      744 non-null    object
#  5   self_employed              1241 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   work_interfere             995 non-null    object
#  9   no_employees               1259 non-null   object
#  10  remote_work                1259 non-null   object
#  11  tech_company               1259 non-null   object
#  12  benefits                   1259 non-null   object
# ...

# %%
#drop the redundant values in the dataset for better observation
df = df.dropna()

# %%
df
# Out:
#                 Timestamp  Age  Gender        Country state self_employed  \
# 24    2014-08-27 11:36:48   33    male  United States    CA            No
# 25    2014-08-27 11:37:08   35    male  United States    TN            No
# 33    2014-08-27 11:39:36   42    Male  United States    WA            No
# 45    2014-08-27 11:43:36   38  Female  United States    TX            No
# 49    2014-08-27 11:44:43   30    male  United States    IL            No
# ...                   ...  ...     ...            ...   ...           ...
# 1186  2014-11-06 11:24:38   56  female  United States    OR           Yes
# 1190  2015-01-03 03:38:30   44       M  United States    OH            No
# 1219  2015-02-21 09:48:13   38    Male  United States    TX            No
# 1221  2015-02-21 10:45:51   46    male  United States    MD            No
# 1249  2015-07-22 18:57:54   30       M  United States    CA            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86 entries, 24 to 1249
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  86 non-null     object
#  1   Age                        86 non-null     int64
#  2   Gender                     86 non-null     object
#  3   Country                    86 non-null     object
#  4   state                      86 non-null     object
#  5   self_employed              86 non-null     object
#  6   family_history             86 non-null     object
#  7   treatment                  86 non-null     object
#  8   work_interfere             86 non-null     object
#  9   no_employees               86 non-null     object
#  10  remote_work                86 non-null     object
#  11  tech_company               86 non-null     object
#  12  benefits                   86 non-null     object
# ...

# %%
#shape of the dataset, too see if the dataset is balanced or not
df.shape
# Out:
# (86, 27)

# %%
x = df['Timestamp'].value_counts()

# %%
x.shape
# Out:
# (86,)

# %%
df['Age'].value_counts()
# Out:
#  35    8
#  34    7
#  27    7
#  30    6
#  38    6
#  40    5
#  43    4
#  39    4
#  33    4
#  25    3
#  26    3
#  37    3
#  32    3
#  42    2
#  41    2
#  23    2
#  50    2
#  31    2
#  36    2
#  29    1
#  21    1
#  8     1
#  56    1
#  55    1
#  44    1
#  45    1
#  46    1
#  48    1
#  49    1
# -1     1
# Name: Age, dtype: int64

# %%
#to know how many null values are still present, if any
df.isna().sum()
# Out:
# Timestamp                    0
# Age                          0
# Gender                       0
# Country                      0
# state                        0
# self_employed                0
# family_history               0
# treatment                    0
# work_interfere               0
# no_employees                 0
# remote_work                  0
# tech_company                 0
# benefits                     0
# care_options                 0
# wellness_program             0
# seek_help                    0
# anonymity                    0
# leave                        0
# mental_health_consequence    0
# phys_health_consequence      0
# coworkers                    0
# supervisor                   0
# mental_health_interview      0
# phys_health_interview        0
# mental_vs_physical           0
# obs_consequence              0
# comments                     0
# dtype: int64

# %%
df['state'].value_counts()
# Out:
# CA    14
# WA    13
# TX     7
# TN     7
# IL     6
# OH     6
# MD     3
# OR     3
# AL     3
# VA     3
# PA     3
# MN     2
# MA     2
# NY     2
# GA     2
# LA     1
# VT     1
# WY     1
# IN     1
# WI     1
# NC     1
# FL     1
# NJ     1
# MI     1
# UT     1
# Name: state, dtype: int64

# %%
df.head(5)
# Out:
#               Timestamp  Age  Gender        Country state self_employed  \
# 24  2014-08-27 11:36:48   33    male  United States    CA            No
# 25  2014-08-27 11:37:08   35    male  United States    TN            No
# 33  2014-08-27 11:39:36   42    Male  United States    WA            No
# 45  2014-08-27 11:43:36   38  Female  United States    TX            No
# 49  2014-08-27 11:44:43   30    male  United States    IL            No
#
#    family_history treatment work_interfere    no_employees  ...  \
# 24            Yes       Yes         Rarely          26-100  ...
# 25            Yes       Yes      Sometimes  More than 1000  ...
# 33            Yes       Yes      Sometimes          26-100  ...
# 45            Yes       Yes      Sometimes          26-100  ...
# 49            Yes       Yes         Rarely          26-100  ...
#
#             leave mental_health_consequence phys_health_consequence  \
# 24     Don't know                        No                      No
# ...

# %%
df.sort_values("Age", inplace = True)
# Out:
# <ipython-input-15-10baa9b1649d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values("Age", inplace = True)

# %%
df['Age'].value_counts()
# Out:
#  35    8
#  34    7
#  27    7
#  30    6
#  38    6
#  40    5
#  43    4
#  39    4
#  33    4
#  25    3
#  26    3
#  37    3
#  32    3
#  42    2
#  41    2
#  23    2
#  50    2
#  31    2
#  36    2
#  29    1
#  21    1
#  8     1
#  56    1
#  55    1
#  44    1
#  45    1
#  46    1
#  48    1
#  49    1
# -1     1
# Name: Age, dtype: int64

# %%
y = df['Age']

# %%
y[1127]
# Out:
# -1

# %%
df.info
# Out:
# <bound method DataFrame.info of                 Timestamp  Age              Gender        Country state  \
# 1127  2014-08-30 20:55:11   -1                   p  United States    AL
# 989   2014-08-29 09:10:58    8  A little about you   Bahamas, The    IL
# 759   2014-08-28 11:34:36   21                Male  United States    IL
# 346   2014-08-27 14:45:12   23                Male  United States    AL
# 224   2014-08-27 13:15:25   23                Male  United States    PA
# ...                   ...  ...                 ...            ...   ...
# 973   2014-08-29 07:51:42   49                Male  United States    GA
# 606   2014-08-27 23:10:16   50                Male  United States    WY
# 898   2014-08-28 17:47:49   50                Male  United States    VA
# 372   2014-08-27 15:21:59   55                   M  United States    PA
# 1186  2014-11-06 11:24:38   56              female  United States    OR
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86 entries, 1127 to 1186
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  86 non-null     object
#  1   Age                        86 non-null     int64
#  2   Gender                     86 non-null     object
#  3   Country                    86 non-null     object
#  4   state                      86 non-null     object
#  5   self_employed              86 non-null     object
#  6   family_history             86 non-null     object
#  7   treatment                  86 non-null     object
#  8   work_interfere             86 non-null     object
#  9   no_employees               86 non-null     object
#  10  remote_work                86 non-null     object
#  11  tech_company               86 non-null     object
#  12  benefits                   86 non-null     object
# ...

# %%
pip install sidetable

# %%
#sidetable is a library that gives more information about the dataset, like the cumulative percentage of the list,etc.
import sidetable as sd

# %%
df.stb.freq(['state'])
# Out:
#    state  count    percent  cumulative_count  cumulative_percent
# 0     CA     14  16.279070                14           16.279070
# 1     WA     13  15.116279                27           31.395349
# 2     TX      7   8.139535                34           39.534884
# 3     TN      7   8.139535                41           47.674419
# 4     OH      6   6.976744                47           54.651163
# 5     IL      6   6.976744                53           61.627907
# 6     VA      3   3.488372                56           65.116279
# 7     PA      3   3.488372                59           68.604651
# 8     OR      3   3.488372                62           72.093023
# 9     MD      3   3.488372                65           75.581395
# 10    AL      3   3.488372                68           79.069767
# 11    NY      2   2.325581                70           81.395349
# 12    MN      2   2.325581                72           83.720930
# ...

# %%
df.stb.freq(['state'], thresh=50)
# Out:
#     state  count    percent  cumulative_count  cumulative_percent
# 0      CA     14  16.279070                14           16.279070
# 1      WA     13  15.116279                27           31.395349
# 2      TX      7   8.139535                34           39.534884
# 3      TN      7   8.139535                41           47.674419
# 4  others     45  52.325581                86          100.000000

# %%
df.head(5)
# Out:
#                 Timestamp  Age              Gender        Country state  \
# 1127  2014-08-30 20:55:11   -1                   p  United States    AL
# 989   2014-08-29 09:10:58    8  A little about you   Bahamas, The    IL
# 759   2014-08-28 11:34:36   21                Male  United States    IL
# 346   2014-08-27 14:45:12   23                Male  United States    AL
# 224   2014-08-27 13:15:25   23                Male  United States    PA
#
#      self_employed family_history treatment work_interfere    no_employees  \
# 1127           Yes            Yes       Yes          Often             1-5
# 989            Yes            Yes       Yes          Often             1-5
# 759             No             No       Yes          Often  More than 1000
# 346             No            Yes       Yes      Sometimes         100-500
# 224             No             No        No          Never          26-100
#
#       ...       leave mental_health_consequence phys_health_consequence  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86 entries, 1127 to 1186
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  86 non-null     object
#  1   Age                        86 non-null     int64
#  2   Gender                     86 non-null     object
#  3   Country                    86 non-null     object
#  4   state                      86 non-null     object
#  5   self_employed              86 non-null     object
#  6   family_history             86 non-null     object
#  7   treatment                  86 non-null     object
#  8   work_interfere             86 non-null     object
#  9   no_employees               86 non-null     object
#  10  remote_work                86 non-null     object
#  11  tech_company               86 non-null     object
#  12  benefits                   86 non-null     object
# ...

# %%
df.stb.freq(['state'], thresh=50, other_label='Rest of states')
# Out:
#             state  count    percent  cumulative_count  cumulative_percent
# 0              CA     14  16.279070                14           16.279070
# 1              WA     13  15.116279                27           31.395349
# 2              TX      7   8.139535                34           39.534884
# 3              TN      7   8.139535                41           47.674419
# 4  Rest of states     45  52.325581                86          100.000000

# %%
df.stb.freq(['state'], value='Age')
# Out:
#    state  Age    percent  cumulative_Age  cumulative_percent
# 0     CA  477  16.001342             477           16.001342
# 1     WA  471  15.800067             948           31.801409
# 2     TX  257   8.621268            1205           40.422677
# 3     TN  242   8.118081            1447           48.540758
# 4     OH  213   7.145253            1660           55.686011
# 5     IL  158   5.300235            1818           60.986246
# 6     VA  126   4.226770            1944           65.213016
# 7     OR  118   3.958403            2062           69.171419
# 8     PA  116   3.891312            2178           73.062731
# 9     MD  107   3.589400            2285           76.652130
# 10    GA   84   2.817846            2369           79.469977
# 11    MA   75   2.515934            2444           81.985911
# 12    NY   65   2.180476            2509           84.166387
# 13    AL   63   2.113385            2572           86.279772
# ...

# %%
#Importing initial libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Import Data
df = pd.read_csv('MENTAL HEALTH DATASET.csv', na_filter=False)
df.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL            NA
# 1  2014-08-27 11:29:37   44       M   United States    IN            NA
# 2  2014-08-27 11:29:44   32    Male          Canada    NA            NA
# 3  2014-08-27 11:29:46   31    Male  United Kingdom    NA            NA
# 4  2014-08-27 11:30:22   31    Male   United States    TX            NA
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   object
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   object
#  3   Country                    1259 non-null   object
#  4   state                      1259 non-null   object
#  5   self_employed              1259 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   work_interfere             1259 non-null   object
#  9   no_employees               1259 non-null   object
#  10  remote_work                1259 non-null   object
#  11  tech_company               1259 non-null   object
#  12  benefits                   1259 non-null   object
# ...

# %%
df.shape
# Out:
# (1259, 27)

# %%
df.describe()
# Out:
#                 Age
# count  1.259000e+03
# mean   7.942815e+07
# std    2.818299e+09
# min   -1.726000e+03
# 25%    2.700000e+01
# 50%    3.100000e+01
# 75%    3.600000e+01
# max    1.000000e+11

# %% [markdown]
# # Data wrangling

# %%
#Drop the unnecessary columns
df.drop(['Timestamp','comments','state'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Age  Gender         Country self_employed family_history treatment  \
# 0   37  Female   United States            NA             No       Yes
# 1   44       M   United States            NA             No        No
# 2   32    Male          Canada            NA             No        No
# 3   31    Male  United Kingdom            NA            Yes       Yes
# 4   31    Male   United States            NA             No        No
#
#   work_interfere    no_employees remote_work tech_company  ...   anonymity  \
# 0          Often            6-25          No          Yes  ...         Yes
# 1         Rarely  More than 1000          No           No  ...  Don't know
# 2         Rarely            6-25          No          Yes  ...  Don't know
# 3          Often          26-100          No          Yes  ...          No
# 4          Never         100-500         Yes          Yes  ...  Don't know
#
#                 leave mental_health_consequence phys_health_consequence  \
# ...

# %%
#check for null values
df.isnull().sum()
# Out:
# Age                          0
# Gender                       0
# Country                      0
# self_employed                0
# family_history               0
# treatment                    0
# work_interfere               0
# no_employees                 0
# remote_work                  0
# tech_company                 0
# benefits                     0
# care_options                 0
# wellness_program             0
# seek_help                    0
# anonymity                    0
# leave                        0
# mental_health_consequence    0
# phys_health_consequence      0
# coworkers                    0
# supervisor                   0
# mental_health_interview      0
# phys_health_interview        0
# mental_vs_physical           0
# obs_consequence              0
# dtype: int64

# %%
#Cleaning the age column
#Check minimum and maximum values of age column
print(df['Age'].min())
print(df['Age'].max())
# Out:
# -1726
# 99999999999

# %%
#Looking for outliers in Age column. Age of employees are generally between 18 and 75.
df[(df['Age'] < 18) | (df['Age'] > 75)]

#So, let's just pick all the records between 18 and 75
#df_survey_data = df_survey_data[(df_survey_data['Age'] >= 18) | (df_survey_data['Age'] <= 75)]
df.drop(df[(df['Age'] < 18) | (df['Age'] > 75)].index, inplace=True)

# %%
df
# Out:
#       Age  Gender         Country self_employed family_history treatment  \
# 0      37  Female   United States            NA             No       Yes
# 1      44       M   United States            NA             No        No
# 2      32    Male          Canada            NA             No        No
# 3      31    Male  United Kingdom            NA            Yes       Yes
# 4      31    Male   United States            NA             No        No
# ...   ...     ...             ...           ...            ...       ...
# 1254   26    male  United Kingdom            No             No       Yes
# 1255   32    Male   United States            No            Yes       Yes
# 1256   34    male   United States            No            Yes       Yes
# 1257   46       f   United States            No             No        No
# 1258   25    Male   United States            No            Yes       Yes
#
#      work_interfere    no_employees remote_work tech_company  ...   anonymity  \
# ...

# %%
#Clean Gender Column
df['Gender'].str.lower().unique()
# Out:
# array(['female', 'm', 'male', 'male-ish', 'maile', 'trans-female',
#        'cis female', 'f', 'something kinda male?', 'cis male', 'woman',
#        'mal', 'male (cis)', 'queer/she/they', 'non-binary', 'femake',
#        'make', 'nah', 'enby', 'fluid', 'genderqueer', 'female ',
#        'androgyne', 'agender', 'cis-female/femme', 'guy (-ish) ^_^',
#        'male leaning androgynous', 'male ', 'man', 'trans woman', 'msle',
#        'neuter', 'female (trans)', 'queer', 'female (cis)', 'mail',
#        'malr', 'femail', 'cis man',
#        'ostensibly male, unsure what that really means'], dtype=object)

# %%
#Creating gender groups 
gender_male = ["male", "m", "male-ish", "maile", "mal", "male (cis)", "make", "male ", "man","msle", "mail", "malr",
            "cis man", "Cis Male", "cis male"]

gender_female = ["cis female", "f", "female", "woman",  "femake", "female ","cis-female/femme", "female (cis)", "femail"]

gender_trans = ["trans-female", "something kinda male?", "queer/she/they", "non-binary","nah", "all", "enby", "fluid",
             "genderqueer", "androgyne", "agender", "male leaning androgynous", "guy (-ish) ^_^", "trans woman",
             "neuter", "female (trans)", "queer", "ostensibly male, unsure what that really means"]

for (row, col) in df.iterrows():

    if str.lower(col.Gender) in gender_male:
        df['Gender'].replace(to_replace=col.Gender, value='male', inplace=True)

    if str.lower(col.Gender) in gender_female:
        df['Gender'].replace(to_replace=col.Gender, value='female', inplace=True)

    if str.lower(col.Gender) in gender_trans:
        df['Gender'].replace(to_replace=col.Gender, value='trans', inplace=True)

#Get rid of unknown values
df = df[~df['Gender'].isin(['A little about you', 'p'])]

print(df['Gender'].unique())
# Out:
# ['female' 'male' 'trans']

# %%
# Cleaning self_employed column
sns.countplot(df['self_employed'])
df['self_employed'].value_counts()
# Out:
# No     1091
# Yes     142
# NA       18
# Name: self_employed, dtype: int64

# %%
# Treating the 18 'NA' values for self_employed as Not Self employed i.e. 'No'
sns.countplot(df['self_employed'])
df['self_employed'] = df['self_employed'].replace('NA', 'Yes')
df['self_employed'].value_counts()
# Out:
# No     1091
# Yes     160
# Name: self_employed, dtype: int64

# %%
df['self_employed'].value_counts()
# Out:
# No     1091
# Yes     160
# Name: self_employed, dtype: int64

# %%
sns.countplot(df['self_employed'])

# %%
sns.countplot(df['work_interfere'])

# %%
# Cleaning work_interfere column - replacing NAs with Unknown
df['work_interfere'] = df['work_interfere'].replace('NA', 'Unknown' )
df['work_interfere'].value_counts()
sns.countplot(df['work_interfere'])

# %% [markdown]
# ### Creating Feature column as ranges of Age

# %%
df['age_bins'] = pd.cut(df['Age'], [0,20,40,60,80], 
                                    labels=["0-20", "21-40", "41-60","61-75"], include_lowest=True)

# %%
#looking at age bins
sns.countplot(df['age_bins'])
df['age_bins'].value_counts()
# Out:
# 21-40    1081
# 41-60     144
# 0-20       22
# 61-75       4
# Name: age_bins, dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
# Number of respondents w.r.t. country
plt.figure(figsize=(16,10))
plt.xticks(rotation=90)
sns.countplot(df['Country'])

# %%
# Do you have a family history?
plt.figure(figsize=(14,10))
plt.subplot(2,2,1)
sns.countplot(df['family_history'])
# Have you sought treatment for a mental health condition?
plt.subplot(2,2,2)
sns.countplot(df['treatment'])
plt.show()
plt.figure(figsize=(14,10))
sns.countplot(df['work_interfere'])

# %%
#If you have a mental health condition, do you feel that it interferes with your work?
labels= ['Sometimes', 'Often', 'Unknown', 'Never','Rarely']
colors=['lightskyblue', 'teal', 'plum', 'palegreen','orange']
sizes= [465,144,264,213,173]

plt.figure(figsize=(14,10))
plt.pie(sizes,labels=labels, colors=colors, startangle=90, autopct='%1.1f%%')
plt.axis('equal')
plt.xlabel('Work Interference')
plt.show()

# %%
# How easy is it for you to take medical leave for a mental health condition?
plt.figure(figsize=(16,10))
plt.subplot(2,2,1)
sns.countplot(df['leave'])
# Do you think that discussing a mental health issue with your employer would have negative consequences?
plt.subplot(2,2,2)
sns.countplot(df['mental_health_consequence'])
# Would you be willing to discuss a mental health issue with your coworkers?
plt.subplot(2,2,3)
sns.countplot(df['coworkers'])
# Would you be willing to discuss a mental health issue with your direct supervisor(s)?
plt.subplot(2,2,4)
sns.countplot(df['supervisor'])
# Have you heard of or observed negative consequences for coworkers with mental health conditions in your workplace?
plt.figure(figsize=(15,6))
sns.countplot(df['obs_consequence'])

# %%
# Does your employer provide mental health benefits?
plt.figure(figsize=(14,10))
plt.subplot(2,2,1)
sns.countplot(df['benefits'])
# Do you know the options for mental health care your employer provides?
plt.subplot(2,2,2)
sns.countplot(df['care_options'])
# Has your employer ever discussed mental health as part of an employee wellness program?
plt.subplot(2,2,3)
sns.countplot(df['wellness_program'])
#Does your employer provide resources to learn more about mental health issues and how to seek help?
plt.subplot(2,2,4)
sns.countplot(df['seek_help'])

# %%
df['work_interfere'].value_counts()
# Out:
# Sometimes    464
# Unknown      262
# Never        212
# Rarely       173
# Often        140
# Name: work_interfere, dtype: int64

# %%
df
# Out:
#       Age  Gender         Country self_employed family_history treatment  \
# 0      37  female   United States           Yes             No       Yes
# 1      44    male   United States           Yes             No        No
# 2      32    male          Canada           Yes             No        No
# 3      31    male  United Kingdom           Yes            Yes       Yes
# 4      31    male   United States           Yes             No        No
# ...   ...     ...             ...           ...            ...       ...
# 1254   26    male  United Kingdom            No             No       Yes
# 1255   32    male   United States            No            Yes       Yes
# 1256   34    male   United States            No            Yes       Yes
# 1257   46  female   United States            No             No        No
# 1258   25    male   United States            No            Yes       Yes
#
#      work_interfere    no_employees remote_work tech_company  ...  \
# ...

# %%
#save the processed data locally
df.to_csv('data_cleaned.csv')
